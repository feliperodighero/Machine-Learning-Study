# %% [markdown]
# <a href="https://colab.research.google.com/github/feliperodighero/Machine-Learning-Study/blob/main/MediaMovel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
data = np.random.normal(0, 1, 100) + np.linspace(0, 1, 100)
data[50] = 10

# %%
plt.plot(data, label='dados')
plt.title('Dados Originais')
plt.legend()
plt.show()

# %%
s = pd.Series(data)
s_ma = s.rolling(window=10).mean()

# %%
plt.plot(s_ma, label='dados')
plt.title('Média móvel')
plt.legend()
plt.show()

# %%
anomalies = s[np.abs(s - s_ma) > 3 * s.std()]

# %%
anomalies
# Out:
# 50    10.0
# dtype: float64

# %%
plt.plot(s, label='dados')
plt.plot(s_ma, label='Média móvel')
plt.plot(anomalies, 'ro', label='Anomalias')
plt.title('Grafico com anomalias')
plt.legend()
plt.show()
